# %% [markdown]
# ## Diabetes Predictions Using Decision Tree Regressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

# %%
dataset['data']
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
dataset['feature_names']
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
dataset['target']
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
df_diabetes = pd.DataFrame(
    dataset.data,
    columns=dataset.feature_names
)
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df_diabetes.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df_diabetes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df_diabetes.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.268604e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
## Independent and dependent features
X=df_diabetes
y=dataset['target']

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train ,X_test , y_train ,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
## correlation
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.136522  0.181976  0.308406  0.261534  0.200301 -0.023100
# sex  0.136522  1.000000  0.044746  0.165128  0.033717  0.128023 -0.344052
# bmi  0.181976  0.044746  1.000000  0.384534  0.246802  0.255519 -0.372335
# bp   0.308406  0.165128  0.384534  1.000000  0.242052  0.164355 -0.113747
# s1   0.261534  0.033717  0.246802  0.242052  1.000000  0.891476  0.044128
# s2   0.200301  0.128023  0.255519  0.164355  0.891476  1.000000 -0.190767
# s3  -0.023100 -0.344052 -0.372335 -0.113747  0.044128 -0.190767  1.000000
# s4   0.165340  0.320619  0.431946  0.209316  0.556987  0.653120 -0.732862
# s5   0.270981  0.121299  0.448657  0.362476  0.528922  0.307541 -0.388778
# s6   0.262201  0.159936  0.394699  0.376421  0.323666  0.298647 -0.304091
#
#            s4        s5        s6
# age  0.165340  0.270981  0.262201
# sex  0.320619  0.121299  0.159936
# bmi  0.431946  0.448657  0.394699
# bp   0.209316  0.362476  0.376421
# s1   0.556987  0.528922  0.323666
# s2   0.653120  0.307541  0.298647
# s3  -0.732862 -0.388778 -0.304091
# s4   1.000000  0.629707  0.441489
# s5   0.629707  1.000000  0.464878
# s6   0.441489  0.464878  1.000000

# %%
# heatmap for correlation
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    root_mean_squared_error,
    median_absolute_error
)

print("R² Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("Median AE:", median_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", root_mean_squared_error(y_test, y_pred))
# Out:
# R² Score: -0.05547696148647652
# MAE: 60.015037593984964
# Median AE: 52.0
# MSE: 5697.789473684211
# RMSE: 75.48370336492647

# %% [markdown]
# ## Hyperparameter Tuning

# %%
param_grid = {
    'criterion': [
        'squared_error',
        'friedman_mse',
        'absolute_error'
    ],

    'splitter': [
        'best',
        'random'
    ],

    'max_depth': [
        None, 2, 3, 4, 5, 7, 10, 15, 20
    ],

    'min_samples_split': [
        2, 5, 10, 20
    ],

    'min_samples_leaf': [
        1, 2, 4, 8
    ],

    'max_features': [
        None, 'sqrt', 'log2'
    ]
}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(
    estimator=regressor,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    refit=True,
    return_train_score=True,
    verbose=3,
    n_jobs=-1
)

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 2592 candidates, totalling 12960 fits
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-6848.952) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-7318.952) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-6146.443) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-5216.613) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-6485.323) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-300.622, test=-6354.510) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-288.206, test=-5140.206) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-244.166, test=-7437.079) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-333.841, test=-6858.015) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-266.644, test=-5636.501) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-659.218, test=-7099.728) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-627.968, test=-6629.199) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-886.571, test=-4732.997) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-939.539, test=-5881.766) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-926.729, test=-6865.812) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-612.809, test=-6578.224) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-905.411, test=-5461.341) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1074.557, test=-4424.024) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-838.182, test=-6173.513) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-1725.320, test=-5788.695) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-753.759, test=-4757.069) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-1859.325, test=-5700.057) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-1835.847, test=-4816.105) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-1774.419, test=-4781.433) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-1997.198, test=-5173.758) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-1817.151, test=-4310.191) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-1495.157, test=-4834.070) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-1294.465, test=-6022.233) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-6043.435) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-1689.828, test=-4643.488) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-1436.368, test=-3593.769) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-2505.176, test=-4519.941) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-2597.213, test=-5270.832) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3089.024, test=-4114.534) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-2743.456, test=-3460.245) total time=   0.0s[CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-2999.981, test=-5501.288) total time=   0.0s
#
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-359.794, test=-6973.120) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-287.249, test=-7036.810) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-348.380, test=-4503.951) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-321.234, test=-6010.698) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-251.572, test=-4990.540) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-960.568, test=-5264.287) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1138.955, test=-5919.461) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1014.119, test=-6759.767) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-785.624, test=-4615.987) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-368.664, test=-6691.918) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1149.679, test=-4268.349) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-434.321, test=-6811.410) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-6223.967) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-447.056, test=-4723.850) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-395.439, test=-4786.088) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1261.443, test=-6257.341) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1377.918, test=-6599.390) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-395.252, test=-6205.023) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1128.251, test=-4552.919) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1084.941, test=-5782.874) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-890.338, test=-5441.227) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-1956.006, test=-6777.655) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2270.768, test=-4451.140) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1009.083, test=-6342.438) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-1767.158, test=-5257.336) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2068.642, test=-5510.995) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-939.905, test=-4000.191) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1123.008, test=-4591.874) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1632.445, test=-4961.415) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-808.472, test=-6954.994) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1437.298, test=-5821.993) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-909.558, test=-5347.183) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-1695.850, test=-6732.045) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1960.955, test=-4331.922) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3238.280, test=-4369.091) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-2751.337, test=-3708.739) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3089.024, test=-4114.534) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-2927.386, test=-5511.994) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1511.162, test=-3034.334) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1689.828, test=-4643.488) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-980.296, test=-4622.796) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1098.162, test=-5428.505) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-2762.629, test=-5143.332) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1185.176, test=-4892.391) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1152.371, test=-3986.957) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=(train=-2401.354, test=-4182.898) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-935.315, test=-6077.628) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=(train=-2404.192, test=-5060.793) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=(train=-2329.809, test=-5314.861) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=(train=-2557.237, test=-4790.740) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=(train=-2572.473, test=-5518.740) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-2404.192, test=-5060.793) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-2329.809, test=-5314.861) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1224.699, test=-5430.817) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1175.314, test=-4303.437) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1152.371, test=-3986.957) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1098.162, test=-5428.505) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-2173.584, test=-4838.862) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1070.991, test=-6026.777) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-2572.473, test=-5518.740) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-935.315, test=-6077.628) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-2401.354, test=-4182.898) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=best;, score=(train=-1825.357, test=-4639.967) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1354.048, test=-4982.159) total time=   0.0s[CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-980.296, test=-4622.796) total time=   0.0s
#
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-2557.237, test=-4790.740) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-2700.389, test=-4685.121) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1185.176, test=-4892.391) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=best;, score=(train=-1669.239, test=-3116.995) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-2471.321, test=-4490.099) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=random;, score=(train=-3168.469, test=-5224.650) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1178.915, test=-3698.473) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=best;, score=(train=-1702.508, test=-5767.288) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=random;, score=(train=-2881.530, test=-3854.381) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=random;, score=(train=-3268.432, test=-4354.027) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-7319.435) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-2570.160, test=-4132.105) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=random;, score=(train=-3306.634, test=-4998.833) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-2518.353, test=-4630.607) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=best;, score=(train=-1960.955, test=-4331.922) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=(train=-1782.058, test=-4589.811) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=random;, score=(train=-2896.789, test=-4452.444) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=(train=-2003.319, test=-4076.676) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=(train=-1823.194, test=-5649.091) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=(train=-3398.748, test=-4749.391) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=20, splitter=best;, score=(train=-2186.201, test=-4401.893) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=(train=-1887.133, test=-3349.316) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=(train=-2026.658, test=-3661.648) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=(train=-1782.058, test=-4589.811) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=(train=-3385.966, test=-4400.574) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=(train=-3114.895, test=-4048.056) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-5814.597) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=(train=-1823.194, test=-5649.091) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=(train=-3166.122, test=-5302.996) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=(train=-3114.895, test=-4048.056) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=(train=-2003.319, test=-4076.676) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-6703.968) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=(train=-2003.319, test=-4076.676) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=(train=-1887.133, test=-3349.316) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=(train=-3346.775, test=-5261.383) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=(train=-2026.658, test=-3661.648) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=(train=-2026.658, test=-3661.648) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=(train=-3346.775, test=-5261.383) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=(train=-3398.748, test=-4749.391) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=(train=-1887.133, test=-3349.316) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=(train=-3166.122, test=-5302.996) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=(train=-3398.748, test=-4749.391) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=(train=-3385.966, test=-4400.574) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=(train=-3166.122, test=-5302.996) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=(train=-1782.058, test=-4589.811) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-1915.998, test=-4359.052) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3096.582, test=-5068.015) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=(train=-3385.966, test=-4400.574) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-5849.516) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-1887.133, test=-3349.316) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3584.110, test=-3941.248) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-7267.871) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=(train=-1823.194, test=-5649.091) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-6943.871) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-1942.886, test=-5724.646) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-9988.097) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=(train=-3114.895, test=-4048.056) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-5719.623) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-0.000, test=-6984.145) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3218.745, test=-4864.989) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=(train=-3346.775, test=-5261.383) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-6512.435) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1272.516, test=-5165.559) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-5677.097) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-461.085, test=-7753.377) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1688.924, test=-6818.036) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-2026.550, test=-4128.067) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-8223.823) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1267.590, test=-6122.648) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3345.538, test=-5501.636) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-901.732, test=-6755.636) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-2351.127, test=-3975.552) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-337.627, test=-7977.211) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3260.428, test=-4774.726) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2356.864, test=-7216.368) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1497.784, test=-5766.384) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-8116.000) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-362.886, test=-5849.228) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-558.029, test=-5520.163) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-374.290, test=-7488.859) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2461.249, test=-4015.395) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1380.628, test=-4864.906) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2087.799, test=-5640.471) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-907.622, test=-6059.955) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1009.910, test=-5585.096) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2438.678, test=-5416.613) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3345.709, test=-5779.099) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-2201.838, test=-5556.480) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-490.285, test=-8607.425) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2341.738, test=-5467.372) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-672.345, test=-5555.816) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-2997.585, test=-5072.218) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2468.353, test=-6472.297) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-829.949, test=-5745.318) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2831.478, test=-4317.211) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-491.683, test=-4763.709) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-3115.677, test=-4914.805) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3365.361, test=-3942.503) total time=   0.0s[CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2052.273, test=-4838.274) total time=   0.0s
#
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-792.939, test=-6529.642) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-2202.670, test=-4688.611) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-602.321, test=-6485.490) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2616.513, test=-4172.249) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2429.651, test=-5411.083) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-749.447, test=-4281.652) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-2083.896, test=-6880.719) total time=   0.0s[CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2883.259, test=-5463.524) total time=   0.0s
#
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1134.945, test=-4259.304) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2185.223, test=-3562.156) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-2365.304, test=-6163.791) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2052.273, test=-4838.274) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2312.158, test=-4041.937) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1366.774, test=-4812.224) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3185.321, test=-5459.555) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-2083.923, test=-6091.268) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1335.191, test=-6791.014) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2311.433, test=-5067.590) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-2068.380, test=-5499.010) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3337.930, test=-4618.843) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2490.928, test=-5418.517) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1750.933, test=-4221.974) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1476.024, test=-5668.112) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1441.701, test=-3692.835) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3056.610, test=-4657.174) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1497.784, test=-5766.384) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1947.510, test=-5352.267) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1712.740, test=-5178.551) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3172.244, test=-5200.101) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1654.836, test=-4899.906) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2181.095, test=-4088.444) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1802.311, test=-6198.504) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1470.328, test=-5077.124) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-468.361, test=-7357.221) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1368.954, test=-4612.306) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3365.361, test=-3942.503) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2724.710, test=-4092.889) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1730.785, test=-5267.041) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2305.487, test=-5337.135) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1861.601, test=-5424.022) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1512.457, test=-5748.930) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-3321.867, test=-4407.971) total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3399.457, test=-5222.426) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=(train=-3432.534, test=-5496.903) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-488.923, test=-6244.892) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1530.723, test=-4473.831) total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-3554.152, test=-4822.247) total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, splitter=random;, score=(train=-3273.598, test=-5877.068) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=(train=-1779.722, test=-4809.829) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=(train=-1712.740, test=-5178.551) total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=(train=-3622.879, test=-3803.059) total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=(train=-1730.785, test=-5267.041) total time=   0.0s
# ...
# [CV 5/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=best;, score=(train=-2163.970, test=-3058.955) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-129.737, test=-7001.403) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3276.105, test=-5589.246) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1216.308, test=-7886.133) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-15.322, test=-6860.565) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3253.646, test=-5001.722) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1166.176, test=-5329.609) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-40.820, test=-6950.262) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3626.034, test=-4204.984) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-0.000, test=-9078.742) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-4083.107, test=-4882.331) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-1086.848, test=-6315.476) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-84.538, test=-8342.295) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=20, splitter=random;, score=(train=-3532.756, test=-4579.873) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=(train=-985.323, test=-8320.049) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-396.271, test=-5663.109) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-71.455, test=-7216.359) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-576.994, test=-6880.540) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-51.231, test=-8787.230) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-837.040, test=-7090.976) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-687.020, test=-6142.911) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-47.441, test=-6598.895) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-403.889, test=-5883.452) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-83.664, test=-6619.065) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-647.055, test=-7445.653) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=(train=-429.030, test=-5588.033) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=(train=-24.750, test=-6370.061) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1578.524, test=-6784.427) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-824.312, test=-3198.129) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-1103.773, test=-4658.097) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1214.528, test=-5427.746) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-671.808, test=-8062.540) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1631.265, test=-5403.242) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-668.789, test=-5313.262) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-110.941, test=-5060.766) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1543.822, test=-6551.032) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=(train=-584.375, test=-6248.066) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-185.289, test=-8768.569) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=(train=-1590.944, test=-6135.340) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=(train=-479.847, test=-8517.324) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1438.241, test=-5393.125) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-2159.777, test=-4951.016) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1032.474, test=-6653.508) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1670.996, test=-5250.911) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1656.427, test=-4965.339) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1479.796, test=-5074.254) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1645.346, test=-4363.706) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=(train=-1554.710, test=-5769.668) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1370.510, test=-7903.169) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2971.713, test=-5341.927) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2980.826, test=-6008.859) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=(train=-1657.466, test=-8012.787) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2955.883, test=-4532.141) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1399.812, test=-7192.516) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2957.275, test=-7328.702) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=(train=-2933.355, test=-5072.094) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1235.433, test=-7155.319) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2554.000, test=-5346.919) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2402.441, test=-5230.625) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1518.536, test=-4663.637) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2720.796, test=-5085.891) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2245.640, test=-6762.815) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1139.512, test=-4639.060) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=(train=-2655.446, test=-5560.086) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3581.261, test=-4408.190) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=(train=-1308.615, test=-4817.250) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3528.372, test=-5245.008) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2303.271, test=-7271.710) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3690.130, test=-6342.036) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3201.692, test=-5973.806) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2446.623, test=-4940.552) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=(train=-3051.567, test=-7269.258) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2563.860, test=-3445.069) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-939.741, test=-6654.806) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2579.512, test=-4844.415) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=(train=-781.004, test=-7606.262) total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=(train=-2576.778, test=-5370.025) total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1754.982, test=-6462.742) total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-1619.741, test=-6317.569) total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2134.862, test=-4076.560) total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=20, splitter=best;, score=(train=-2011.490, test=-3852.694) total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [None, 2, 3, 4, 5, 7, 10, 15, 20],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4, 8],
#                          'min_samples_split': [2, 5, 10, 20],
#                          'splitter': ['best', 'random']},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
print("Best Parameters:")
print(grid.best_params_)

print("\nBest Score:")
print(grid.best_score_)

print("\nBest Estimator:")
print(grid.best_estimator_)
# Out:
# Best Parameters:
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Best Score:
# -3995.9590080435214
#
# Best Estimator:
# DecisionTreeRegressor(max_depth=3, min_samples_leaf=8, random_state=42)

# %%
## predictions
y_pred1=grid.predict(X_test)

# %%
print("R² Score:", r2_score(y_test, y_pred1))
print("MAE:", mean_absolute_error(y_test, y_pred1))
print("Median AE:", median_absolute_error(y_test, y_pred1))
print("MSE:", mean_squared_error(y_test, y_pred1))
print("RMSE:", root_mean_squared_error(y_test, y_pred1))
# Out:
# R² Score: 0.40581497124548527
# MAE: 45.420587169785406
# Median AE: 37.01724137931035
# MSE: 3207.593652721904
# RMSE: 56.6356217651215

# %%
best_tree = grid.best_estimator_

# %%
train_pred = best_tree.predict(X_train)

test_pred = best_tree.predict(X_test)

print("Train R²:", r2_score(y_train, train_pred))
print("Test R² :", r2_score(y_test, test_pred))
# Out:
# Train R²: 0.5229417876314364
# Test R² : 0.40581497124548527

# %%
# Plot the optimized tree
plt.figure(figsize=(24,12))
tree.plot_tree(
    best_tree,
    feature_names=X.columns,
    filled=True,
    rounded=True,
    fontsize=10,
    precision=2
)
plt.show()

# Feature Importance
importance = pd.Series(
    best_tree.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

print(importance)

# Plot Feature Importance
plt.figure(figsize=(8,5))
importance.plot(kind='bar')
plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# bmi    0.705861
# s5     0.170434
# bp     0.099330
# s2     0.024375
# age    0.000000
# sex    0.000000
# s1     0.000000
# s3     0.000000
# s4     0.000000
# s6     0.000000
# dtype: float64
